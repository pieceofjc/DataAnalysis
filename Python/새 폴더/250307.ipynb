# %% [markdown]
# #### 시계열데이터
# - type
#     - 년도 표시(4자리수) : %Y
#     - 년도 표시(2자리수) : %y
#     - 월을 숫자로 표시 : %m
#     - 월의 이름을 표시 : %B
#     - 월의 이름을 축약해서 표시 : %b
#     - 일을 숫자로 표시 : %d
#     - 시를 24시 기준으로 표시 : %H
#     - 시를 12시 기준으로 표시 : %I
#     - AM/PM을 표시 : %p
#     - 분을 숫자로 표시 : %M
#     - 초를 숫자로 표시 : %S
#     - 요일을 이름으로 표시 : %A
#     - 요일을 숫자로 표시 : %w ( 0 : 일, ... , 6 : 토 )

# %%
from datetime import datetime

# %%
time_text = "2025-03-07"

# %%
type(time_text)
# Out:
# str

# %%
# 문자열 데이터를 시계열 데이터로 변경
time_data = datetime.strptime(time_text, '%Y-%m-%d')
print(time_data)
print(time_text)
# Out:
# 2025-03-07 00:00:00
# 2025-03-07

# %%
print(type(time_data))
# Out:
# <class 'datetime.datetime'>

# %%
# 시계열 데이터를 문자열 데이터로 변경
time_data.strftime('%y/%m/%d')
# Out:
# '25/03/07'

# %%
time_data.strftime('%m월')
# Out:
# '03월'

# %%
time_data.strftime('%w')
# Out:
# '5'

# %%
time_data.strftime('%a')
# Out:
# 'Fri'

# %%
import pandas as pd

# %%
# pandas에서 제공하는 시계열 데이터 
pd.Timestamp(100000)    # 나노초 단위로 시간을 구한다.
# Out:
# Timestamp('1970-01-01 00:00:00.000100')

# %%
pd.Timestamp(100, unit='D')
# Out:
# Timestamp('1970-04-11 00:00:00')

# %%
pd.Timestamp('98-03-07')
# Out:
# Timestamp('1998-03-07 00:00:00')

# %%
pd.Timestamp("2016-01")
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
time_data2 = pd.to_datetime('2025년 03월 07일', format="%Y년 %m월 %d일")

# %%
time_data3 = pd.Timestamp(1, unit='D')

# %%
time_data2 - time_data3
# Out:
# Timedelta('20153 days 00:00:00')

# %%
pd.Timedelta("3 days")
# Out:
# Timedelta('3 days 00:00:00')

# %%
time_data2 - pd.Timedelta('3 days')
# Out:
# Timestamp('2025-03-04 00:00:00')

# %%
time_data2 - pd.Timedelta(days= 30)
# Out:
# Timestamp('2025-02-05 00:00:00')

# %%
corona = pd.read_csv("./data/csv/corona.csv")

# %%
corona.head()
# Out:
#    Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
# 0           0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
# 1           1  2022-06-07 09:09:00.897     24299   18174842  903  20220607
# 2           2  2022-06-06 09:00:06.734     24279   18168670  902  20220606
# 3           3  2022-06-05 08:53:19.426     24258   18163648  901  20220605
# 4           4  2022-06-04 08:56:49.219     24238   18153814  900  20220604
#
#   stateTime                 updateDt  accExamCnt  accDefRate
# 0     00:00                      NaN         NaN         NaN
# 1     00:00  2022-06-08 09:10:36.846         NaN         NaN
# 2     00:00  2022-06-08 09:10:50.441         NaN         NaN
# 3     00:00  2022-06-08 09:11:04.758         NaN         NaN
# 4     00:00  2022-06-08 09:11:26.303         NaN         NaN

# %%
# 요일별 평균 일일 확진자의 수가 가장 큰 요일은 언제인가?
# 사용할 컬럼들만 추출하여 변수에 저장
df = corona[ ['stateDt', 'decideCnt'] ]

# %%
df.head()
# Out:
#     stateDt  decideCnt
# 0  20220608   18188200
# 1  20220607   18174842
# 2  20220606   18168670
# 3  20220605   18163648
# 4  20220604   18153814

# %%
# 일일확진자 컬럼을 생성 2
df2 = df.copy()
df2.sort_values('stateDt', inplace=True)
df2['일일확진자'] = df2['decideCnt'] - df2['decideCnt'].shift(1).fillna(0)

# %%
df2.tail()
# Out:
#     stateDt  decideCnt    일일확진자
# 4  20220604   18153814  12039.0
# 3  20220605   18163648   9834.0
# 2  20220606   18168670   5022.0
# 1  20220607   18174842   6172.0
# 0  20220608   18188200  13358.0

# %%
# 일일확진자 컬럼을 생성
df3 = df.copy()
df3['일일확진자'] = df3['decideCnt'] - df3['decideCnt'].shift(-1).fillna(0)

# %%
df3.head()
# Out:
#     stateDt  decideCnt    일일확진자
# 0  20220608   18188200  13358.0
# 1  20220607   18174842   6172.0
# 2  20220606   18168670   5022.0
# 3  20220605   18163648   9834.0
# 4  20220604   18153814  12039.0

# %%
# 일일확진자 컬럼을 생성
df4 = df.copy()
df4['일일확진자'] = df4['decideCnt'].diff(-1).fillna(0)

# %%
df4.head()
# Out:
#     stateDt  decideCnt    일일확진자
# 0  20220608   18188200  13358.0
# 1  20220607   18174842   6172.0
# 2  20220606   18168670   5022.0
# 3  20220605   18163648   9834.0
# 4  20220604   18153814  12039.0

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   stateDt    820 non-null    int64
#  1   decideCnt  820 non-null    int64
#  2   일일확진자      820 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 19.3 KB

# %%
# int64 -> 시계열데이터
df4['stateDt'] = (pd.to_datetime(df4['stateDt'], format="%Y%m%d"))

# %%
df4.head()
# Out:
#      stateDt  decideCnt    일일확진자 요일
# 0 2022-06-08   18188200  13358.0  3
# 1 2022-06-07   18174842   6172.0  2
# 2 2022-06-06   18168670   5022.0  1
# 3 2022-06-05   18163648   9834.0  0
# 4 2022-06-04   18153814  12039.0  6

# %%
dayofweek = []
for i in range(len(df4['stateDt'])):
    dayofweek.append(datetime.strftime(df4.loc[i, 'stateDt'], '%w'))

# %%
# map으로 바꾸기
df4['요일'] = df4['stateDt'].map(lambda x: x.strftime('%w'))
df4
# Out:
#        stateDt  decideCnt    일일확진자 요일
# 0   2022-06-08   18188200  13358.0  3
# 1   2022-06-07   18174842   6172.0  2
# 2   2022-06-06   18168670   5022.0  1
# 3   2022-06-05   18163648   9834.0  0
# 4   2022-06-04   18153814  12039.0  6
# ..         ...        ...      ... ..
# 815 2020-03-14       8086    107.0  6
# 816 2020-03-13       7979    110.0  5
# 817 2020-03-12       7869    114.0  4
# 818 2020-03-11       7755    242.0  3
# 819 2020-03-10       7513      0.0  2
#
# [820 rows x 4 columns]

# %%
week = ['일','월','화','수','목','금','토']
result = []
for i in range(len(df4['요일'])):
    result.append(week[int(df4.loc[i, '요일'])])

df4['요일(한글)'] = result

# %%
# while, dictionary 쓰기
week = {
    '0':'일',
    '1':'월',
    '2':'화',
    '3':'수',
    '4':'목',
    '5':'금',
    '6':'토'
}
result2 = []
i = 0
length = len(df4['요일'])
while i < length:
    result2.append(week[df4.loc[i, '요일']])
    i+=1
result2
# Out:
# ['수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화',
#  '월',
#  '일',
#  '토',
#  '금',
#  '목',
#  '수',
#  '화']

# %%
df4
# Out:
#        stateDt  decideCnt    일일확진자 요일 요일(한글)
# 0   2022-06-08   18188200  13358.0  3      수
# 1   2022-06-07   18174842   6172.0  2      화
# 2   2022-06-06   18168670   5022.0  1      월
# 3   2022-06-05   18163648   9834.0  0      일
# 4   2022-06-04   18153814  12039.0  6      토
# ..         ...        ...      ... ..    ...
# 815 2020-03-14       8086    107.0  6      토
# 816 2020-03-13       7979    110.0  5      금
# 817 2020-03-12       7869    114.0  4      목
# 818 2020-03-11       7755    242.0  3      수
# 819 2020-03-10       7513      0.0  2      화
#
# [820 rows x 5 columns]

# %%
# map으로 바꾸기
week = ['일','월','화','수','목','금','토']
df4['요일'] = df4['요일'].map(lambda x: week[int(x)])
# df4['요일'].map(lambda x: week[int(x)])
# Out:
# 0      수
# 1      화
# 2      월
# 3      일
# 4      토
#       ..
# 815    토
# 816    금
# 817    목
# 818    수
# 819    화
# Name: 요일, Length: 820, dtype: object

# %%
df4.head()
# Out:
#      stateDt  decideCnt    일일확진자 요일
# 0 2022-06-08   18188200  13358.0  3
# 1 2022-06-07   18174842   6172.0  2
# 2 2022-06-06   18168670   5022.0  1
# 3 2022-06-05   18163648   9834.0  0
# 4 2022-06-04   18153814  12039.0  6

# %%
df5 = df4.drop(819,axis=0).copy()

# %%
df5 = df5.groupby(['요일(한글)'])[['일일확진자']].mean().sort_values('일일확진자', ascending=False)

# %%
df5.reset_index()
# Out:
#   요일(한글)         일일확진자
# 0      수  26994.550847
# 1      목  25776.267241
# 2      토  22555.948718
# 3      금  22542.854701
# 4      화  21969.837607
# 5      일  20801.384615
# 6      월  14739.230769

# %%
# 시각화
import matplotlib.pyplot as plt

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='요일(한글)'>
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\SAMSUNG\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# font 설정
import platform

# %%
if platform.system() == "Darwin":
    plt.rc('font', family = "AppleGothic")
else:
    plt.rc('font', family = "Malgun Gothic")

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='요일(한글)'>
